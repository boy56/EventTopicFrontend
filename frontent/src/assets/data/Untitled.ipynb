# %%
import json

# %%
with open("xuanti_data.json",encoding='utf-8') as f:
    data = json.load(f)

# %%
data
# Out:
# [{'score': 0,
#   'esIndex': '',
#   'parentid': '',
#   'simids': [],
#   'timestamp': '',
#   'type2': 107,
#   'type1': 18,
#   'type0': 9,
#   'type': '南海',
#   'secu': -1,
#   'gfw': 0,
#   'risk': -1,
#   'recommend': -1,
#   'importance': -1,
#   'hot': 31,
#   'emotion': 2,
#   'id': 3499701686357512330,
#   'datatag': 'even',
#   'customer': '中国广播网',
#   'location': '其他',
#   'corewords': '',
#   'time': '2019-11-22T10:11:32.698Z',
#   'url': 'http://g5.m.cnr.cn/h5/524869148_uczzd_20191122.html?zzd_from=uc-iflow',
#   'user': '',
#   'userview': 236.0,
#   'userid': '',
#   'title': '外交部：反对以“航行自由”为借口损害中国主权安全',
#   'text': '',
#   'country_l': '中国 中国',
#   'content_l': '国家立场'},
#  {'score': 0,
#   'esIndex': '',
#   'parentid': '',
#   'simids': [],
#   'timestamp': '',
#   'type2': 107,
#   'type1': 18,
#   'type0': 9,
#   'type': '南海',
#   'secu': -1,
#   'gfw': 0,
#   'risk': -1,
#   'recommend': -1,
#   'importance': -1,
#   'hot': 1,
#   'emotion': 2,
# ...
