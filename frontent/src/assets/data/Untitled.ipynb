# %%
import json

# %%
with open("data.json",encoding='utf-8') as f:
    data = json.load(f)

# %%
data
# Out:
# {'event1': [[22, 6, '2019-11-22', 0, 0, 0, 0, '外交部：反对以“航行自由<br>为借口损害中国主权安全'],
#   [27, 71, '2019-11-27', 0, 0, 0, 0, '韩国首提南海航海自由 韩<br>：响应美国对华牵制战略'],
#   [22, 6, '2019-11-22', 0, 0, 0, 0, '美舰连续两天在南海非法活动，<br>交部：敦促美方不要逆势而动']],
#  'event2': [[22, 33, '2019-11-22', 0, 0, 0, 0, '美军接连两天在南海<br>动 解放军警告驱离'],
#   [19, 89, '2019-11-19', 0, 0, 0, 0, '美防长称中国在南海活动威胁<br>国 中方：美方唯恐天下不乱'],
#   [20, 18, '2019-11-20', 0, 0, 0, 0, '美防长称反对使用恐吓手段<br>暗批中国走在错误的道路上']],
#  'event3': [[19, 14, '2019-11-19', 0, 0, 0, 0, '外交部：美方“横行自由<br>才是南海局势紧张根源'],
#   [20, 59, '2019-11-20', 0, 0, 0, 0, '美防长指责中国在南海<br>动构成威胁 北京回应'],
#   [23, 13, '2019-11-23', 0, 0, 0, 0, '外交部：反对以航行自由<br>名损害中国主权和安全'],
#   [22, 8, '2019-11-22', 0, 0, 0, 0, '挑衅？美国派军舰连续两天闯中国南<br>岛礁 ，被我军海空兵力警告驱离']],
#  'topics': {'3499701686357512330': {'index': 0,
#    'topic': '南海',
#    'date': '2019-11-22',
#    'text': '外交部：反对以“航行自由”为借口损害中国主权安全',
#    'link': 'http://g5.m.cnr.cn/h5/524869148_uczzd_20191122.html?zzd_from=uc-iflow'},
# ...
